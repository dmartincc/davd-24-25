# %% [markdown]
# # Prueba Intertrimestral
#
# **Nombre:**
#
# **Apellidos:**
#
# **Tiempo de la prueba: 2 Horas**
#
# **Asignatura:** Desarrollo de Aplicaciones para la Visualización de Datos
#
# **Fecha:** 18 de octubre de 2023
#
# **Instrucciones:**
#
# - Escribe código limpio y autoexplicativo.
#
# - Se eliminará 0.5 puntos por usar Seaborn o Matplotlib.
#
# - Se pueden utilizar los materiales de clase.
#
# - Se puede utilizar internet para búsqueda de dudas y documentación.
#
# - No se puede utilizar ningún tipo de LLM.
#
# - No se puede utilizar mensajería instantánea.
#
# - Imprime una versión en PDF del notebook y envialo a dmartincorral@icai.comillas.edu
#
#
# ## Librerías

# %%
import pandas as pd
import numpy as np
import sklearn.datasets

import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import (
    r2_score,
    mean_absolute_error,
    mean_squared_error,
    classification_report,
    confusion_matrix
)
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import SGDClassifier, LogisticRegression

# %% [markdown]
# ## Ejercicio 1 (2 puntos):
#
# a) Crea una función que calcule y devuelva el factorial de un número entero. **(0.6 puntos)**
#
# b) Crea una función que verifique si un número es primo o no. **(0.6 puntos)**
#
# c) Muestra en un dataframe los 50 primeros números positivos, si es primo y su factorial utilizando las funciones anteriores. **(0.6 puntos)**
#
# d) ¿Cómo se podría programar en una clase las tres operaciones anteriores? **(0.2 puntos)**

# %% [markdown]
# a) Crea una función que calcule y devuelva el factorial de un número entero. **(0.6 puntos)**

# %%
def fact(n):
  fac = None
  if isinstance(n, int) and n >= 0:
    fac = 1
    if n > 0:
      for i in range(1, n + 1):
        fac = fac*i
  return fac

print(fact(-1))
print(fact(1.2))
print(fact(0))
print(fact(3))
# Out:
# None
# None
# 1
# 6

# %% [markdown]
# b) Crea una función que verifique si un número es primo o no. **(0.6 puntos)**

# %%
def even(n):
  return True if (n % 2) == 0 else False

print(even(10))
print(even(3))
# Out:
# True
# False

# %% [markdown]
# c) Muestra en un dataframe los 50 primeros números positivos, si es primo y su factorial utilizando las funciones anteriores. **(0.6 puntos)**

# %%
df = pd.DataFrame(columns=['n', 'even', 'fact'])

for i in range(1, 51):
  df.loc[i] = [i, even(i), fact(i)]

print(df.shape)
df.head()
# Out:
# (50, 3)
#    n   even fact
# 1  1  False    1
# 2  2   True    2
# 3  3  False    6
# 4  4   True   24
# 5  5  False  120

# %% [markdown]
# d) ¿Cómo se podría programar en una clase las tres operaciones anteriores? **(0.2 puntos)**

# %%
class data():

  def __init__(self):
    df = pd.DataFrame(columns=['n', 'even', 'fact'])
    self.df = df
    self.fac = None

  def fact(self, n):
    fac = self.fac
    if isinstance(n, int) and n >= 0:
      fac = 1
      if n > 0:
        for i in range(1, n + 1):
          fac = fac*i
    return fac

  def even(self, n):
    return True if (n % 2) == 0 else False

  def run(self, start, end):
    for i in range(start, end):
      self.df.loc[i] = [i, self.even(i), self.fact(i)]
    return self.df


d = data()
df = d.run(-5, 5)
print(df.shape)
df.head(10)
# Out:
# (10, 3)
#     n   even  fact
# -5 -5  False  None
# -4 -4   True  None
# -3 -3  False  None
# -2 -2   True  None
# -1 -1  False  None
#  0  0   True     1
#  1  1  False     1
#  2  2   True     2
#  3  3  False     6
#  4  4   True    24

# %% [markdown]
# ## Ejercicio 2 (4 puntos):
#
# a) Extrae de sklearn el conjunto de datos __California Housing dataset__
#  y transfórmalo a dataframe de pandas **(0.25 puntos)**
#
# b) Construye una función que muestra la estructura del dataset, el número de NAs, tipos de variables y estadísticas básicas de cada una de las variables. **(0.5 puntos)**
#
# c) Construye una __Regresión lineal__ y un __Random forest__ que predigan el __Median house value__ según los datos disponibles. **(0.75 puntos)**
#
# d) Visualiza cuales son las variables (coeficientes) más importantes en cada uno de los modelos. **(1.25 puntos)**
#
# e) Decide a través de las métricas que consideres oportunas, cuál de los dos modelos es mejor, por qué y explica el proceso que has realizado para responder en los puntos anteriores. **(1.25 puntos)**

# %% [markdown]
# a) Extrae de sklearn el conjunto de datos __California Housing dataset__
#  y transfórmalo a dataframe de pandas **(0.25 puntos)**

# %%
dataset = sklearn.datasets.fetch_california_housing()

df = pd.DataFrame(data = dataset['data'], columns = dataset['feature_names'])
df["target"] = dataset["target"]

df.to_csv("fetch_california_housing.csv")

print(df.head())
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  target
# 0    -122.23   4.526
# 1    -122.22   3.585
# 2    -122.24   3.521
# 3    -122.25   3.413
# 4    -122.25   3.422

# %% [markdown]
# b) Construye una función que muestra la estructura del dataset, el número de NAs, tipos de variables y estadísticas básicas de cada una de las variables. **(0.5 puntos)**

# %%
def basicStats(df):
  print(df.shape)
  print(df.isna().sum())
  print(df.dtypes)
  print(df.describe(include='all'))

basicStats(df)
# Out:
# (20640, 9)
# MedInc        0
# HouseAge      0
# AveRooms      0
# AveBedrms     0
# Population    0
# AveOccup      0
# Latitude      0
# Longitude     0
# target        0
# dtype: int64
# MedInc        float64
# HouseAge      float64
# AveRooms      float64
# AveBedrms     float64
# Population    float64
# AveOccup      float64
# Latitude      float64
# Longitude     float64
# target        float64
# dtype: object
#              MedInc      HouseAge      AveRooms     AveBedrms    Population  \
# count  20640.000000  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.870671     28.639486      5.429000      1.096675   1425.476744
# std        1.899822     12.585558      2.474173      0.473911   1132.462122
# min        0.499900      1.000000      0.846154      0.333333      3.000000
# 25%        2.563400     18.000000      4.440716      1.006079    787.000000
# 50%        3.534800     29.000000      5.229129      1.048780   1166.000000
# 75%        4.743250     37.000000      6.052381      1.099526   1725.000000
# max       15.000100     52.000000    141.909091     34.066667  35682.000000
#
#            AveOccup      Latitude     Longitude        target
# count  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.070655     35.631861   -119.569704      2.068558
# std       10.386050      2.135952      2.003532      1.153956
# min        0.692308     32.540000   -124.350000      0.149990
# 25%        2.429741     33.930000   -121.800000      1.196000
# 50%        2.818116     34.260000   -118.490000      1.797000
# 75%        3.282261     37.710000   -118.010000      2.647250
# max     1243.333333     41.950000   -114.310000      5.000010

# %% [markdown]
# c) Construye una __Regresión lineal__ y un __Random forest__ que predigan el __Median house value__ según los datos disponibles. **(0.75 puntos)**

# %%
X = df.loc[:, df.columns!= 'target']
y = df['target']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 123)

lm = Pipeline(steps=[
  ('scaler', StandardScaler()),
  ("lm", LinearRegression()),
])

lm = lm.fit(X_train, y_train)

print("Variance explanation R^2 = {}".format(round(lm.score(X, y),2)))

rf = RandomForestRegressor().fit(X_train, y_train)

rf = Pipeline(steps=[
  ('scaler', StandardScaler()),
  ("rf", RandomForestRegressor()),
])

rf = rf.fit(X_train, y_train)

print("Variance explanation R^2 = {}".format(round(rf.score(X, y),2)))
# Out:
# Variance explanation R^2 = 0.61
# Variance explanation R^2 = 0.94

# %% [markdown]
# d) Visualiza cuales son las variables (coeficientes) más importantes en cada uno de los modelos. **(1.25 puntos)**

# %%
lmc = lm.named_steps['lm'].coef_
rfc = rf.named_steps['rf'].feature_importances_

print(lmc)

# Plot for LM
objects = X.columns
y_pos = np.arange(len(objects))
coefficients = lmc

fig = go.Figure()

# Agrego las trazas necesarias
fig.add_trace(
    go.Bar(
        x = coefficients,
        y = objects,
        name = "Coeficientes",
        orientation='h'
    )
)

# Actualizo el diseño
fig.update_layout(title = "LM coefficients importance", xaxis_title = "Coeficientes", yaxis_title = "Variables")

# Muestro la figura
fig.show()


print(rfc)

# Plot for RF
objects = X.columns
y_pos = np.arange(len(objects))
coefficients = rfc

fig = go.Figure()

# Agrego las trazas necesarias
fig.add_trace(
    go.Bar(
        x = coefficients,
        y = objects,
        name = "Coeficientes",
        orientation='h'
    )
)

# Actualizo el diseño
fig.update_layout(title = "RF coefficients importance", xaxis_title = "Coeficientes", yaxis_title = "Variables")

# Muestro la figura
fig.show()
# Out:
# [ 0.83601038  0.11522131 -0.28190146  0.31828994 -0.00740408 -0.04168267
#  -0.89014951 -0.85554916]
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="5cbd05b5-ef4c-4cf8-8fce-157f600b8d64" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5cbd05b5-ef4c-4cf8-8fce-157f600b8d64")) {                    Plotly.newPlot(                        "5cbd05b5-ef4c-4cf8-8fce-157f600b8d64",                        [{"name":"Coeficientes","orientation":"h","x":[0.8360103808417605,0.1152213080345197,-0.2819014638963006,0.318289939595821,-0.007404075998708815,-0.04168266872036112,-0.8901495097142252,-0.8555491614570055],"y":["MedInc","HouseAge","AveRooms","AveBedrms","Population","AveOccup","Latitude","Longitude"],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"c ...
# [0.52168747 0.05290077 0.04678487 0.0297808  0.03170158 0.13443393
#  0.09217089 0.09053969]
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="9b8d9ce8-f077-45bf-a0dd-96b1d1fc1062" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9b8d9ce8-f077-45bf-a0dd-96b1d1fc1062")) {                    Plotly.newPlot(                        "9b8d9ce8-f077-45bf-a0dd-96b1d1fc1062",                        [{"name":"Coeficientes","orientation":"h","x":[0.521687473934014,0.0529007701981791,0.04678486947416427,0.029780799946060848,0.03170158212456978,0.13443392961957581,0.09217088760480481,0.09053968709863144],"y":["MedInc","HouseAge","AveRooms","AveBedrms","Population","AveOccup","Latitude","Longitude"],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"co ...

# %% [markdown]
# e) Decide a través de las métricas que consideres oportunas, cuál de los dos modelos es mejor, por qué y explica el proceso que has realizado para responder en los puntos anteriores. **(1.25 puntos)**

# %%
y_pred = lm.predict(X_test)

print("Mean squared error: %.2f" % mean_squared_error(y_test, y_pred))
print("Mean absolute error: %.2f" % mean_absolute_error(y_test, y_pred))
print("Coefficient of determination: %.2f" % r2_score(y_test, y_pred))

y_pred = rf.predict(X_test)

print("Mean squared error: %.2f" % mean_squared_error(y_test, y_pred))
print("Mean absolute error: %.2f" % mean_absolute_error(y_test, y_pred))
print("Coefficient of determination: %.2f" % r2_score(y_test, y_pred))
# Out:
# Mean squared error: 0.52
# Mean absolute error: 0.53
# Coefficient of determination: 0.61
# Mean squared error: 0.25
# Mean absolute error: 0.33
# Coefficient of determination: 0.81

# %% [markdown]
# *Consideremos* el dataset que contiene __The Most Streamed Spotify Songs 2023__ que se encuentra en el respositorio.
#
# Información de las variables:
#
# - track_name: Name of the song
# - artist(s)_name: Name of the artist(s) of the song
# - vartist_count: Number of artists contributing to the song
# - released_year: Year when the song was released
# - released_month: Month when the song was released
# - release_day: Day of the month when the song was released
# - in_spotify_playlists: Number of Spotify playlists the song is included in
# - in_spotify_charts: Presence and rank of the song on Spotify charts
# - streams: Total number of streams on Spotify
# - in_apple_playlists: Number of Apple Music playlists the song is included in
# - in_apple_charts: Presence and rank of the song on Apple Music charts
# - in_deezer_playlists: Number of Deezer playlists the song is included in
# - in_deezer_charts: Presence and rank of the song on Deezer charts
# - in_shazam_charts: Presence and rank of the song on Shazam charts
# - bpm: Beats per minute, a measure of song tempo
# - key: Key of the song
# - mode: Mode of the song (major or minor)
# - danceability_%: Percentage indicating how suitable the song is for dancing
# - valence_%: Positivity of the song's musical content
# - energy_%: Perceived energy level of the song
# - acousticness_%: Amount of acoustic sound in the song
# - instrumentalness_%: Amount of instrumental content in the song
# - liveness_%: Presence of live performance elements
# - speechiness_%: Amount of spoken words in the song
#
# Para las respuestas b, c, d, e, f y g es imperativo acompañarlas respuestas con una visualización.
#
# a) Lee el fichero en formato dataframe, aplica la función del ejercicio 2.b, elimina NAs y convierte a integer si fuera necesario. **(0.25 puntos)**
#
# b) ¿Cuántos artistas únicos hay? **(0.25 puntos)**
#
# c) ¿Cuál es la distribución de reproducciones? **(0.5 puntos)**
#
# d) ¿Existe una diferencia signitificativa en las reproducciones entre las canciones de un solo artista y las de más de uno? **(0.5 puntos)**
#
# e) ¿Cuáles son las propiedades de una canción que mejor correlan con el número de reproducciones de una canción? **(0.5 puntos)**
#
# f) ¿Cuáles son las variables que mejor predicen un hit? **(1 puntos)**
#
# *Nota: Crea una variable binaria (Hit/No Hit) en base a 3.c, crea una regresión logística y visualiza sus coeficientes.*
#
# e) Agrupa los 4 gráficos realizados en uno solo y haz una recomendación a un sello discográfico para producir un nuevo hit. **(1 puntos)**

# %% [markdown]
# a) Lee el fichero en formato dataframe, aplica la función del ejercicio 2.b, elimina NAs y convierte a integer si fuera necesario. **(0.25 puntos)**

# %%
df = pd.read_csv("https://raw.githubusercontent.com/dmartincc/davd-23-24/main/Prueba_Intertrimestral/spotify-2023.csv", encoding='ISO-8859-1')
print(df.head())
basicStats(df)
# Out:
#                             track_name    artist(s)_name  artist_count  \
# 0  Seven (feat. Latto) (Explicit Ver.)  Latto, Jung Kook             2
# 1                                 LALA       Myke Towers             1
# 2                              vampire    Olivia Rodrigo             1
# 3                         Cruel Summer      Taylor Swift             1
# 4                       WHERE SHE GOES         Bad Bunny             1
#
#    released_year  released_month  released_day  in_spotify_playlists  \
# 0           2023               7            14                   553
# 1           2023               3            23                  1474
# 2           2023               6            30                  1397
# 3           2019               8            23                  7858
# 4           2023               5            18                  3133
#
#    in_spotify_charts    streams  in_apple_playlists  ...  bpm key   mode  \
# 0                147  141381703                  43  ...  125   B  Major
# 1                 48  133716286                  48  ...   92  C#  Major
# 2                113  140003974                  94  ...  138   F  Major
# 3                100  800840817                 116  ...  170   A  Major
# 4                 50  303236322                  84  ...  144   A  Minor
#
#   danceability_%  valence_% energy_% acousticness_%  instrumentalness_%  \
# 0             80         89       83             31                   0
# 1             71         61       74              7                   0
# 2             51         32       53             17                   0
# 3             55         58       72             11                   0
# 4             65         23       80             14                  63
#
#    liveness_%  speechiness_%
# 0           8              4
# 1          10              4
# 2          31              6
# 3          11             15
# 4          11              6
#
# [5 rows x 24 columns]
# (953, 24)
# track_name               0
# artist(s)_name           0
# artist_count             0
# released_year            0
# released_month           0
# released_day             0
# in_spotify_playlists     0
# in_spotify_charts        0
# streams                  0
# in_apple_playlists       0
# in_apple_charts          0
# in_deezer_playlists      0
# in_deezer_charts         0
# in_shazam_charts        50
# bpm                      0
# key                     95
# mode                     0
# danceability_%           0
# valence_%                0
# energy_%                 0
# acousticness_%           0
# instrumentalness_%       0
# liveness_%               0
# speechiness_%            0
# dtype: int64
# track_name              object
# artist(s)_name          object
# artist_count             int64
# released_year            int64
# released_month           int64
# released_day             int64
# in_spotify_playlists     int64
# in_spotify_charts        int64
# streams                 object
# in_apple_playlists       int64
# in_apple_charts          int64
# in_deezer_playlists     object
# in_deezer_charts         int64
# in_shazam_charts        object
# bpm                      int64
# key                     object
# mode                    object
# danceability_%           int64
# valence_%                int64
# energy_%                 int64
# acousticness_%           int64
# instrumentalness_%       int64
# liveness_%               int64
# speechiness_%            int64
# dtype: object
#        track_name artist(s)_name  artist_count  released_year  released_month  \
# count         953            953    953.000000     953.000000      953.000000
# unique        943            645           NaN            NaN             NaN
# top      Daylight   Taylor Swift           NaN            NaN             NaN
# freq            2             34           NaN            NaN             NaN
# mean          NaN            NaN      1.556139    2018.238195        6.033578
# std           NaN            NaN      0.893044      11.116218        3.566435
# min           NaN            NaN      1.000000    1930.000000        1.000000
# 25%           NaN            NaN      1.000000    2020.000000        3.000000
# 50%           NaN            NaN      1.000000    2022.000000        6.000000
# 75%           NaN            NaN      2.000000    2022.000000        9.000000
# max           NaN            NaN      8.000000    2023.000000       12.000000
#
#         released_day  in_spotify_playlists  in_spotify_charts    streams  \
# count     953.000000            953.000000         953.000000        953
# unique           NaN                   NaN                NaN        949
# top              NaN                   NaN                NaN  723894473
# freq             NaN                   NaN                NaN          2
# mean       13.930745           5200.124869          12.009444        NaN
# std         9.201949           7897.608990          19.575992        NaN
# min         1.000000             31.000000           0.000000        NaN
# 25%         6.000000            875.000000           0.000000        NaN
# 50%        13.000000           2224.000000           3.000000        NaN
# 75%        22.000000           5542.000000          16.000000        NaN
# max        31.000000          52898.000000         147.000000        NaN
#
#         in_apple_playlists  ...         bpm  key   mode danceability_%  \
# count           953.000000  ...  953.000000  858    953      953.00000
# unique                 NaN  ...         NaN   11      2            NaN
# top                    NaN  ...         NaN   C#  Major            NaN
# freq                   NaN  ...         NaN  120    550            NaN
# mean             67.812172  ...  122.540399  NaN    NaN       66.96957
# std              86.441493  ...   28.057802  NaN    NaN       14.63061
# min               0.000000  ...   65.000000  NaN    NaN       23.00000
# 25%              13.000000  ...  100.000000  NaN    NaN       57.00000
# 50%              34.000000  ...  121.000000  NaN    NaN       69.00000
# 75%              88.000000  ...  140.000000  NaN    NaN       78.00000
# max             672.000000  ...  206.000000  NaN    NaN       96.00000
#
#          valence_%    energy_% acousticness_%  instrumentalness_%  liveness_%  \
# count   953.000000  953.000000     953.000000          953.000000  953.000000
# unique         NaN         NaN            NaN                 NaN         NaN
# top            NaN         NaN            NaN                 NaN         NaN
# freq           NaN         NaN            NaN                 NaN         NaN
# mean     51.431270   64.279119      27.057712            1.581322   18.213012
# std      23.480632   16.550526      25.996077            8.409800   13.711223
# min       4.000000    9.000000       0.000000            0.000000    3.000000
# 25%      32.000000   53.000000       6.000000            0.000000   10.000000
# 50%      51.000000   66.000000      18.000000            0.000000   12.000000
# 75%      70.000000   77.000000      43.000000            0.000000   24.000000
# max      97.000000   97.000000      97.000000           91.000000   97.000000
#
#         speechiness_%
# count      953.000000
# unique            NaN
# top               NaN
# freq              NaN
# mean        10.131165
# std          9.912888
# min          2.000000
# 25%          4.000000
# 50%          6.000000
# 75%         11.000000
# max         64.000000
#
# [11 rows x 24 columns]

# %%
df = df.dropna()
df['streams'] = pd.to_numeric(df['streams'], errors='coerce')
basicStats(df)
# Out:
# (817, 24)
# track_name              0
# artist(s)_name          0
# artist_count            0
# released_year           0
# released_month          0
# released_day            0
# in_spotify_playlists    0
# in_spotify_charts       0
# streams                 1
# in_apple_playlists      0
# in_apple_charts         0
# in_deezer_playlists     0
# in_deezer_charts        0
# in_shazam_charts        0
# bpm                     0
# key                     0
# mode                    0
# danceability_%          0
# valence_%               0
# energy_%                0
# acousticness_%          0
# instrumentalness_%      0
# liveness_%              0
# speechiness_%           0
# dtype: int64
# track_name               object
# artist(s)_name           object
# artist_count              int64
# released_year             int64
# released_month            int64
# released_day              int64
# in_spotify_playlists      int64
# in_spotify_charts         int64
# streams                 float64
# in_apple_playlists        int64
# in_apple_charts           int64
# in_deezer_playlists      object
# in_deezer_charts          int64
# in_shazam_charts         object
# bpm                       int64
# key                      object
# mode                     object
# danceability_%            int64
# valence_%                 int64
# energy_%                  int64
# acousticness_%            int64
# instrumentalness_%        int64
# liveness_%                int64
# speechiness_%             int64
# dtype: object
#        track_name artist(s)_name  artist_count  released_year  released_month  \
# count         817            817    817.000000     817.000000      817.000000
# unique        811            571           NaN            NaN             NaN
# top      Miss You   Taylor Swift           NaN            NaN             NaN
# freq            2             29           NaN            NaN             NaN
# mean          NaN            NaN      1.567931    2018.457772        6.018360
# std           NaN            NaN      0.876211      10.829267        3.572554
# min           NaN            NaN      1.000000    1930.000000        1.000000
# 25%           NaN            NaN      1.000000    2021.000000        3.000000
# 50%           NaN            NaN      1.000000    2022.000000        5.000000
# 75%           NaN            NaN      2.000000    2022.000000        9.000000
# max           NaN            NaN      8.000000    2023.000000       12.000000
#
#         released_day  in_spotify_playlists  in_spotify_charts       streams  \
# count     817.000000            817.000000         817.000000  8.160000e+02
# unique           NaN                   NaN                NaN           NaN
# top              NaN                   NaN                NaN           NaN
# freq             NaN                   NaN                NaN           NaN
# mean       13.696450           4849.898409          11.722154  4.689858e+08
# std         9.299663           7741.126455          18.617668  5.231267e+08
# min         1.000000             31.000000           0.000000  2.762000e+03
# 25%         5.000000            829.000000           0.000000  1.342848e+08
# 50%        13.000000           2040.000000           3.000000  2.638368e+08
# 75%        22.000000           4890.000000          16.000000  6.011986e+08
# max        31.000000          52898.000000         147.000000  3.562544e+09
#
#         in_apple_playlists  ...         bpm  key   mode danceability_%  \
# count           817.000000  ...  817.000000  817    817     817.000000
# unique                 NaN  ...         NaN   11      2            NaN
# top                    NaN  ...         NaN   C#  Major            NaN
# freq                   NaN  ...         NaN  115    452            NaN
# mean             60.161567  ...  122.565483  NaN    NaN      67.391677
# std              74.923594  ...   28.174803  NaN    NaN      14.688458
# min               0.000000  ...   65.000000  NaN    NaN      23.000000
# 25%              12.000000  ...   99.000000  NaN    NaN      57.000000
# 50%              32.000000  ...  120.000000  NaN    NaN      70.000000
# 75%              78.000000  ...  141.000000  NaN    NaN      79.000000
# max             532.000000  ...  206.000000  NaN    NaN      96.000000
#
#          valence_%    energy_% acousticness_%  instrumentalness_%  liveness_%  \
# count   817.000000  817.000000     817.000000          817.000000  817.000000
# unique         NaN         NaN            NaN                 NaN         NaN
# top            NaN         NaN            NaN                 NaN         NaN
# freq           NaN         NaN            NaN                 NaN         NaN
# mean     51.201958   64.362301      26.309670            1.676867   18.168911
# std      23.620978   16.107587      25.470972            8.767328   13.541996
# min       4.000000   14.000000       0.000000            0.000000    3.000000
# 25%      32.000000   53.000000       5.000000            0.000000   10.000000
# 50%      51.000000   66.000000      17.000000            0.000000   12.000000
# 75%      70.000000   76.000000      41.000000            0.000000   24.000000
# max      97.000000   97.000000      97.000000           91.000000   97.000000
#
#         speechiness_%
# count      817.000000
# unique            NaN
# top               NaN
# freq              NaN
# mean        10.526316
# std         10.219987
# min          2.000000
# 25%          4.000000
# 50%          6.000000
# 75%         12.000000
# max         64.000000
#
# [11 rows x 24 columns]
# <ipython-input-44-75f2b69f65ce>:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# b) ¿Cuántos artistas únicos hay? **(0.25 puntos)**

# %%
results = set()
df['artist(s)_name'].str.lower().str.split(', ').apply(results.update)
print(results)
print(len(results))
# Out:
# {'stars music chile', '', 'feid', 'kali uchis', 'luciano', 'lauren spencer smith', 'mc livinho', 'andy williams', 'dave', 'ruth b.', 'snoop dogg', 'bï¿½ï¿½jo', 'sam smith', 'dina rae', 'kanii', 'miguel', 'schï¿½ï¿½rze', 'lasso', 'league of legends', 'em beihold', 'abhijay sharma', 'muni long', 'linkin park', 'southstar', 'becky g', 'mahmood', 'the ronettes', 'vishal dadlani', 'tyler cole', 'radiohead', 'hozier', 'kalush', 'shakira', 'sebastian yatra', 'avicii', 'yoasobi', 'xxxtentacion', 'ellie goulding', 'future', 'amitabha bhattacharya', 'ha sung woon', 'tesla jnr', 'yung gravy', 'eladio carrion', 'kumaar', 'zakaria', 'dj matt d', 'zendaya', 'v', 'c. tangana', 'roger', 'mnek', 'teto', 'mc ryan sp', 'doï¿½ï¿½u ', 'twisted', 'lyanno', 'kodak black', 'anggi marito', 'vance joy', 'lana del rey', 'zach bryan', 'xamï¿½ï¿½', 'twice', 'calum scott', 'mufasa & hypeman', 'don toliver', 'luis r conriquez', 'dj escobar', 'zï¿½ï¿½ neto & crist', 'grupo frontera', 'supernova ent', 'mc caverinha', 'selena g', 'metro boomin', 'styrx', 'macklemore', 'foudeqush', 'yeat', 'j balvin', 'blake shelton', 'dababy', 'ella henderson', 'dopamine', 'junior h', 'peso pluma', 'elton john', 'bl', 'bts', 'tyler', 'nickoog clk', 'arctic monkeys', 'tomorrow x together', 'ali sethi', 'aerosmith', 'shawn mendes', 'ive', 'the anxiety', 'dove cameron', 'kanye west', 'omar apollo', 'luude', 'diane guerrero', 'megan thee stallion', 'lord huron', 'ryan castro', 'lizzy mcalpine', 'iu', 'yung lean', 'tulus', 'manuel turizo', 'mari fernandez', 'simone mendes', 'gabito ballesteros', 'kelly clarkson', 'travis scott', 'nicki minaj', 'lf system', 'dazy', 'acraze', '21 savage', 'leo santana', 'grupo marca registrada', 'christian nodal', 'kayblack', 'olga merediz', 'pedro sampaio', 'mambo kingz', 'taeyang', 'phoebe bridgers', 'ovy on the drums', 'mert demir', 'saweetie', 'ed sheeran', 'raim laode', 'stephanie beatriz', 'elley duhï¿', 'chris rea', 'nle choppa', 'lit killah', 'the plastic ono band', 'beach weather', 'charlie puth', 'bizarrap', 'thezth', 'latto', 'prezioso', 'mitchell ayres & his orchestra', 'shae gill', 'fran c', 'ryan lewis', 'sampha', 'tate m', 'jax jones', 'karol g', 'kendrick lamar', 'topher ngo', 'grayson vill', 'natanael cano', 'beï¿½ï', 'silk sonic', '347aidan', 'paul mccartney', 'tiï¿½ï¿½sto', 'yoko ono', 'jin', 'eminem', 'saiko', 'polima westcoast', 'libianca', 'lil yachty', 'john scott trotter & his orchestra', 'altamash faridi', 'aventura', 'yuridia', 'tears for fears', 'steve aoki', 'bradley cooper', 'drake', 'ghost', 'kordhell', 'a$ap rocky', 'rosalï¿½', 'lil uzi vert', 'darlene love', 'suga', 'wiu', 'duki', 'riton', 'daddy yankee', 'enhypen', 'bellakath', 'chanel', 'semicenk', 'tanna leone', 'mainstreet', 'mahalini', 'eden muï¿½ï', 'pinkpantheress', 'nayeon', 'neo b', 'quevedo', 'mae stephens', 'amitabh bhattacharya', 'tainy', 'offset', 'el chachito', 'frank ocean', 'maroon 5', 'tate mcrae', 'chris brown', 'angela aguilar', 'danny ocean', 'marï¿½ï¿½lia mendo', 'wisin & yandel', 'migrantes', 'colde', 'sales', 'david kushner', 'fivio foreign', 'luke combs', 'nengo flow', 'justin bieber', 'l-gante', 'dalex', 'newjeans', 'the neighbourhood', 'george henrique &', 'jain', 'trueno', 'varun jain', 'paloma mami', 'meghan trainor', 'the rare occasions', 'halsey', 'chris jedi', 'zï¿½ï¿½ fe', 'alicia keys', 'dr. dre', 'dj 900', 'beam', 'ludwig goransson', 'the marï¿½ï', 'mc menor sg', '(g)i-dle', 'eric church', 'fireboy dml', 'ray dalton', 'jisoo', 'kyla', 'sped up 8282', 'post malone', 'peso p', 'fifty fifty', 'pailita', 'alvaro diaz', 'os gemeos da putaria', 'ariana grande', 'blanco', 'james blake', 'adele', 'riar saab', 'l7nnon', 'sachin-jigar', 'frank sinatra', 'yandel', 'marï¿½ï¿½lia mendonï¿½ï¿½a', 'charli xcx', 'dennis', 'joji', 'the harlem community choir', 'maldy', 'dido', 'summer walker', 'pharrell williams', 'thxsomch', 'skrillex', 'robin schulz', 'ana castela', 'kaliii', 'lil cake', 'stray kids', 'ice spice', 'kate bush', 'jhayco', 'nicky youre' ...
# 628

# %% [markdown]
# c) ¿Cuál es la distribución de reproducciones? **(0.5 puntos)**

# %%
print(df.streams.describe())

fig = px.histogram(df, x="streams",
                   labels = {"streams": "Reproducciones"},
                   histnorm='probability density',
                   nbins = 100,
                   opacity=0.6)

fig.update_traces(marker_color = "darkorange")
fig.show()
# Out:
# count    8.160000e+02
# mean     4.689858e+08
# std      5.231267e+08
# min      2.762000e+03
# 25%      1.342848e+08
# 50%      2.638368e+08
# 75%      6.011986e+08
# max      3.562544e+09
# Name: streams, dtype: float64
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="569702d6-09a4-43a2-bf16-8c195a8571ae" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("569702d6-09a4-43a2-bf16-8c195a8571ae")) {                    Plotly.newPlot(                        "569702d6-09a4-43a2-bf16-8c195a8571ae",                        [{"alignmentgroup":"True","bingroup":"x","histnorm":"probability density","hovertemplate":"Reproducciones=%{x}\u003cbr\u003eprobability density=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"darkorange","opacity":0.6,"pattern":{"shape":""}},"name":"","nbinsx":100,"offsetgroup":"","orientation":"v","showlegend":false,"x":[141381703.0,133716286.0,140003974.0,800840817.0,303236322.0,183706234.0,725980112.0,58149378.0,95217315.0,553634067.0,505671438.0,58255150.0,387570742.0,1163093654.0,496795686.0,335222234.0,363369738.0,86444842.0,52135248.0,200647221.0,115364561.0,78300654.0,899183384.0,61245289.0,429829812.0,127408954.0,22581161.0,52294266.0,843957510.0,999748277.0,618990393.0,188933502.0,1355959075.0,786181836.0,176553476.0,354495408.0,2808096550.0,1109433169.0,1047101291.0,570515054.0,1647990401.0,2565529693.0,518745108.0,107753850.0,177740666.0,153372011.0,57876440.0,256483385.0,1214083358.0,111947664.0,156338624.0,720434240.0,357925728.0,674072710.0,1755214421.0,404562836.0,373199958.0,14780425.0,39578178.0,54266102.0,751134527.0,1356565093.0,1592909789.0,635412045.0,1230675890.0,585695368.0,43857627.0,2009094673.0,600976848.0,39709092.0,39228929.0,2665343922.0,223633238.0,1440757818.0,165484133.0,58054811.0,157058870.0,95131998.0,250305248.0,685032533.0,38411956.0,144565150.0,127567540.0,399686758.0,983637508.0,118482347.0,882831184.0,286400165.0,172825906.0,1241559043.0,29562220.0,77309611.0,1605224506.0,1116995633.0,838079900.0,1163620694.0,1093605526.0,179659294.0,39058561.0,36912123.0,1205951614.0,1791000570.0,201660859.0,248088961.0,90839753.0,607123776.0,55842345.0,211050784.0,342897938.0,2762.0,601863821.0,1953533826.0,2355719893.0,66902503.0,96273746.0,430977451.0,284819874.0,721975598.0,276259178.0,54225632.0,2559529074.0,681583126.0,2594040133.0,81102253.0,11956641.0,1687664027.0,611700552.0,1133865788.0,1089402494.0,411747614.0,255932395.0,31873544.0,233801632.0,1481349984.0,142095275.0,2011464183.0,436027885.0,2713922350.0,621660989.0,950906471.0,1593270737.0,1410088830.0,1235005533.0,1374581173.0,94186466.0,1788326445.0,1840364617.0,143573775.0,684675814.0,1113838873.0,1267333350.0,3562543890.0,1271293243.0,265882712.0,841749534.0,47956378.0,806397070.0,1641426668.0,2135158446.0,367316268.0,350381515.0,1264310836.0,30343206.0,405136812.0,540654286.0,57312735.0,397582059.0,1479115056.0,86773632.0,133753727.0,123124076.0,463564958.0,64533040.0,65496046.0,68616963.0,161460990.0,70106975.0,113509496.0,89933133.0,71007139.0,43522589.0,232896922.0,37126685.0,195576623.0,532336353.0,538115192.0,46142772.0,401036314.0,127026613.0,345031710.0,288101651.0,60350538.0,335074782.0,76767396.0,46065667.0,459276435.0,39666245.0,138517666.0,822633917.0,595900742.0,51985779.0,57945987.0,115010040.0,175097833.0,57089066.0,488386797.0,32761689.0,1047480053.0,153454328.0,217672943.0,457184829.0,726434358.0,573633020.0,1406111294.0,71573339.0,24975653.0,145458418.0,1424589568.0,231332117.0,415932686.0,988515741.0,50847624.0,39893489.0,92035115.0,118810253.0,77233241.0,117747907.0,266624541.0,293186992.0,139681964.0,123132751.0,103762518.0,162887075.0,91221625.0,190490915.0,96180277.0,185240616.0,885093467.0,104992946.0,147290338.0,158950978.0,76910644.0,137123880.0,782369383.0,502574952.0,207033255.0,381161027.0,466231982.0,357580552.0,61105704.0,198275403.0,705469769.0,34502215.0,304118600.0,1449799467.0,173627354.0,90025258.0,652704649.0,182 ...

# %% [markdown]
# d) ¿Existe una diferencia signitificativa en las reproducciones entre las canciones de un solo artista y las de más de uno? **(0.5 puntos)**

# %%
df['more_two_artists'] = df["artist_count"] > 1
df.head()

# Distributions for each group
print(df[df['more_two_artists'] == True]['streams'].describe())
print(df[df['more_two_artists'] == False]['streams'].describe())

# Boxplot
fig = go.Figure()

fig.add_trace(
    go.Box(
        x = df[df['more_two_artists'] == True]["streams"],
        marker_color = "gold",
        name = "Más de dos",
        boxpoints='all',
        boxmean=True
    )
)

fig.add_trace(
    go.Box(
        x = df[df['more_two_artists'] == False]["streams"],
        marker_color = "mediumseagreen",
        name = "Un solo artista",
        boxpoints='all',
        boxmean=True
    )
)

fig.update_layout(title = "Distribución de reproducciones", yaxis_title = "")

fig.show()

# T-test
from scipy.stats import ttest_ind

group1 = df[df['more_two_artists'] == True]['streams']
group2 = df[df['more_two_artists'] == False]['streams']

ttest_ind(group1.dropna(), group2.dropna(), trim=.2)
# Out:
# count    3.230000e+02
# mean     4.118884e+08
# std      5.029107e+08
# min      2.762000e+03
# 25%      1.103616e+08
# 50%      2.233199e+08
# 75%      5.352258e+08
# max      2.808097e+09
# Name: streams, dtype: float64
# count    4.930000e+02
# mean     5.063944e+08
# std      5.331516e+08
# min      1.478042e+07
# 25%      1.562147e+08
# 50%      2.996482e+08
# 75%      6.815831e+08
# max      3.562544e+09
# Name: streams, dtype: float64
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="24abf61b-92c0-472f-a11f-8d1c9cbaa349" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("24abf61b-92c0-472f-a11f-8d1c9cbaa349")) {                    Plotly.newPlot(                        "24abf61b-92c0-472f-a11f-8d1c9cbaa349",                        [{"boxmean":true,"boxpoints":"all","marker":{"color":"gold"},"name":"M\u00e1s de dos","x":[141381703.0,183706234.0,725980112.0,553634067.0,505671438.0,335222234.0,86444842.0,200647221.0,115364561.0,899183384.0,61245289.0,52294266.0,843957510.0,618990393.0,188933502.0,354495408.0,2808096550.0,1109433169.0,1047101291.0,2565529693.0,518745108.0,107753850.0,177740666.0,111947664.0,156338624.0,720434240.0,357925728.0,674072710.0,54266102.0,1356565093.0,1230675890.0,585695368.0,600976848.0,39709092.0,2665343922.0,223633238.0,1440757818.0,58054811.0,250305248.0,144565150.0,286400165.0,1605224506.0,1093605526.0,39058561.0,248088961.0,90839753.0,55842345.0,211050784.0,2762.0,1953533826.0,2355719893.0,66902503.0,721975598.0,276259178.0,54225632.0,81102253.0,11956641.0,611700552.0,1133865788.0,233801632.0,142095275.0,436027885.0,2713922350.0,1235005533.0,94186466.0,367316268.0,57312735.0,86773632.0,133753727.0,463564958.0,64533040.0,161460990.0,70106975.0,113509496.0,89933133.0,71007139.0,43522589.0,37126685.0,532336353.0,538115192.0,46142772.0,401036314.0,127026613.0,288101651.0,60350538.0,46065667.0,39666245.0,138517666.0,51985779.0,57945987.0,115010040.0,57089066.0,32761689.0,573633020.0,71573339.0,24975653.0,231332117.0,50847624.0,92035115.0,77233241.0,266624541.0,162887075.0,96180277.0,104992946.0,147290338.0,158950978.0,76910644.0,207033255.0,61105704.0,198275403.0,705469769.0,34502215.0,304118600.0,90025258.0,652704649.0,655466831.0,146409671.0,95816024.0,100409613.0,80758350.0,325592432.0,58473276.0,77377503.0,116334601.0,477033549.0,294352144.0,223582566.0,471819764.0,116599790.0,497225336.0,105062254.0,139836056.0,221409663.0,58890931.0,93438910.0,609293408.0,93587665.0,1223481149.0,263453310.0,1435127549.0,236857112.0,309483971.0,1061966512.0,1065580332.0,1365184.0,184308753.0,606361689.0,120972253.0,140187018.0,556585270.0,174006928.0,78489819.0,195516622.0,972509632.0,213438580.0,1802514301.0,462791599.0,90598517.0,460492795.0,94005786.0,110073250.0,473248298.0,155653938.0,395591396.0,295998468.0,136689549.0,110649992.0,323437194.0,116144341.0,608228647.0,180577478.0,809306935.0,614555082.0,78139948.0,322336177.0,349585590.0,674772936.0,88103848.0,1575467011.0,91656026.0,539595276.0,578207856.0,775542072.0,656013912.0,240684449.0,236940480.0,393230256.0,673801126.0,383550148.0,530511203.0,1763363713.0,374191487.0,436695353.0,354065229.0,311395144.0,672656250.0,686734357.0,261414174.0,610045621.0,1115880852.0,594482982.0,566954746.0,184937148.0,60680939.0,154797871.0,261286503.0,422691058.0,263894529.0,956865266.0,427486004.0,355219175.0,489945871.0,1223481149.0,720825549.0,593917618.0,200972675.0,560222750.0,528544703.0,2159346687.0,651732901.0,863756573.0,1695712020.0,223319934.0,54937991.0,258316038.0,596152090.0,177129919.0,716591492.0,1210599487.0,843309044.0,107255472.0,135079152.0,426204830.0,327498031.0,245400167.0,579395142.0,675039469.0,252871192.0,918915401.0,1180896317.0,143139338.0,209768491.0,64714573.0,81350745.0,64787943.0,2484812918.0,461437791.0,759208783.0,299634472.0,756907987.0,208166039.0,94616487.0,153240879.0,2204080728.0,2591224264.0,236872197.0,349746291.0,273005485.0,75476209.0,187772591.0,178512385.0,176290831.0,106933107.0,197643795.0,933815613.0,120847157.0,237351106.0,127309180.0,123216717.0,479655659.0,344055883.0,68895644.0,86176890.0,319546754.0,76831876.0,307752576.0,1304313953.0,58687425.0,212109195.0,284249832.0,33381454.0,184622518.0,30 ...
# TtestResult(statistic=-2.824056811668969, pvalue=0.004935201415216841, df=490.0)

# %% [markdown]
# e) ¿Cuáles son las propiedades de una canción que mejor correlan con el número de reproducciones de una canción? **(0.5 puntos)**

# %%
print(df.corr())
px.imshow(df.corr())
# Out:
#                       artist_count  released_year  released_month  \
# artist_count              1.000000       0.073564        0.033857
# released_year             0.073564       1.000000        0.076439
# released_month            0.033857       0.076439        1.000000
# released_day             -0.014762       0.166377        0.057784
# in_spotify_playlists     -0.085226      -0.390729       -0.122407
# in_spotify_charts        -0.008570       0.068679       -0.050186
# streams                  -0.109760      -0.242726       -0.046041
# in_apple_playlists       -0.017024      -0.201474       -0.034029
# in_apple_charts          -0.075271       0.003479       -0.017813
# in_deezer_charts          0.020585       0.095741        0.006942
# bpm                      -0.058844      -0.011570       -0.049400
# danceability_%            0.214078       0.215032       -0.054808
# valence_%                 0.123650      -0.047643       -0.110355
# energy_%                  0.137530       0.078886       -0.086897
# acousticness_%           -0.094704      -0.133224        0.055046
# instrumentalness_%       -0.061269      -0.023958        0.035481
# liveness_%                0.034354       0.008489        0.001329
# speechiness_%             0.131486       0.129887        0.042127
# more_two_artists          0.802076       0.109444        0.020383
#
#                       released_day  in_spotify_playlists  in_spotify_charts  \
# artist_count             -0.014762             -0.085226          -0.008570
# released_year             0.166377             -0.390729           0.068679
# released_month            0.057784             -0.122407          -0.050186
# released_day              1.000000             -0.107616           0.016068
# in_spotify_playlists     -0.107616              1.000000           0.141343
# in_spotify_charts         0.016068              0.141343           1.000000
# streams                  -0.025116              0.780404           0.214034
# in_apple_playlists       -0.011916              0.688316           0.208202
# in_apple_charts           0.007727              0.215676           0.556804
# in_deezer_charts          0.055426              0.101283           0.566161
# bpm                      -0.033394             -0.034483           0.028830
# danceability_%            0.084244             -0.096981           0.051338
# valence_%                 0.062751             -0.029823           0.050040
# energy_%                  0.047318              0.035875           0.104963
# acousticness_%            0.000785             -0.064633          -0.072853
# instrumentalness_%        0.023040             -0.024570          -0.005814
# liveness_%               -0.011094             -0.051973          -0.026582
# speechiness_%            -0.014602             -0.077610          -0.094102
# more_two_artists          0.012942             -0.083977           0.043694
#
#                        streams  in_apple_playlists  in_apple_charts  \
# artist_count         -0.109760           -0.017024        -0.075271
# released_year        -0.242726           -0.201474         0.003479
# released_month       -0.046041           -0.034029        -0.017813
# released_day         -0.025116           -0.011916         0.007727
# in_spotify_playlists  0.780404            0.688316         0.215676
# in_spotify_charts     0.214034            0.208202         0.556804
# streams               1.000000            0.735321         0.269137
# in_apple_playlists    0.735321            1.000000         0.364761
# in_apple_charts       0.269137            0.364761         1.000000
# in_deezer_charts      0.184329            0.326815         0.366581
# bpm                  -0.025694            0.005558         0.027057
# danceability_%       -0.093268           -0.012586        -0.026138
# valence_%            -0.051014            0.041253         0.042941
# energy_%             -0.036499            0.039992         0.129354
# acousticness_%       -0.005751           -0.070965        -0.096781
# instrumentalness_%   -0.033039           -0.054372        -0.000381
# liveness_%           -0.056664           -0.064986        -0.007161
# speechiness_%        -0.099968           -0.097647        -0.146472
# more_two_artists     -0.088400            0.009455        -0.015160
#
#                       in_deezer_charts       bpm  danceability_%  valence_%  \
# artist_count                  0.020585 -0.058844        0.214078   0.123650
# released_year                 0.095741 -0.011570        0.215032  -0.047643
# released_month                0.006942 -0.049400       -0.054808  -0.110355
# released_day                  0.055426 -0.033394        0.084244   0.062751
# in_spotify_playlists          0.101283 -0.034483       -0.096981  -0.029823
# in_spotify_charts             0.566161  0.028830        0.051338   0.050040
# streams                       0.184329 -0.025694       -0.093268  -0.051014
# in_apple_playlists            0.326815  0.005558       -0.012586   0.041253
# in_apple_charts               0.366581  0.027057       -0.026138   0.042941
# in_deezer_charts              1.000000  0.021730        0.081414   0.073169
# bpm                           0.021730  1.000000       -0.148174   0.029169
# danceability_%                0.081414 -0.148174        1.000000   0.389729
# valence_%                     0.073169  0.029169        0.389729   1.000000
# energy_%                      0.104350  0.013363        0.157970   0.349736
# acousticness_%               -0.035135 -0.010767       -0.240454  -0.064072
# instrumentalness_%            0.003503 -0.003407       -0.102144  -0.147032
# liveness_%                    0.003650 -0.005817       -0.100579   0.000142
# speechiness_%                -0.081523  0.038248        0.201189   0.035704
# more_two_artists              0.083135 -0.051447        0.246854   0.118007
#
#                       energy_%  acousticness_%  instrumentalness_%  \
# artist_count          0.137530       -0.094704           -0.061269
# released_year         0.078886       -0.133224           -0.023958
# released_month       -0.086897        0.055046            0.035481
# released_day          0.047318        0.000785            0.023040
# in_spotify_playlists  0.035875       -0.064633           -0.024570
# in_spotify_charts     0.104963       -0.072853           -0.005814
# streams              -0.036499       -0.005751           -0.033039
# in_apple_playlists    0.039992       -0.070965           -0.054372
# in_apple_charts       0.129354       -0.096781           -0.000381
# in_deezer_charts      0.104350       -0.035135            0.003503
# bpm                   0.013363       -0.010767           -0.003407
# danceability_%        0.157970       -0.240454           -0.102144
# valence_%             0.349736       -0.064072           -0.147032
# energy_%              1.000000       -0.552637           -0.051662
# acousticness_%       -0.552637        1.000000            0.046700
# instrumentalness_%   -0.051662        0.046700            1.000000
# liveness_%            0.111240       -0.046112           -0.044626
# speechiness_%        -0.026880       -0.017820           -0.090994
# more_two_artists      0.146180       -0.085563           -0.096751
#
#                       liveness_%  speechiness_%  more_two_artists
# artist_count            0.034354       0.131486          0.802076
# released_year           0.008489       0.129887          0.109444
# released_month          0.001329       0.042127          0.020383
# released_day           -0.011094      -0.014602          0.012942
# in_spotify_playlists   -0.051973      -0.077610         -0.083977
# in_spotify_charts      -0.026582      -0.094102          0.043694
# streams                -0.056664      -0.099968         -0.088400
# in_apple_playlists     -0.064986      -0.097647          0.009455
# in_apple_charts        -0.007161      -0.146472         -0.015160
# in_deezer_charts        0.003650      -0.081523          0.083135
# bpm                    -0.005817       0.038248         -0.051447
# danceability_%         -0.100579       0.201189          0.246854
# valence_%               0.000142       0.035704          0.118007
# energy_%                0.111240      -0.026880          0.146180
# acousticness_%         -0.046112      -0.017820         -0.085563
# instrumentalness_%     -0.044626      -0.090994         -0.096751
# liveness_%              1.000000      -0.022807          0.050951
# speechiness_%          -0.022807       1.000000          0.161524
# more_two_artists        0.050951       0.161524          1.000000
# <ipython-input-48-35095072ca4d>:1: FutureWarning:
#
# The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#
# <ipython-input-48-35095072ca4d>:2: FutureWarning:
#
# The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="a30bee40-03e9-458f-bdc7-07ec086cdb13" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a30bee40-03e9-458f-bdc7-07ec086cdb13")) {                    Plotly.newPlot(                        "a30bee40-03e9-458f-bdc7-07ec086cdb13",                        [{"coloraxis":"coloraxis","name":"0","x":["artist_count","released_year","released_month","released_day","in_spotify_playlists","in_spotify_charts","streams","in_apple_playlists","in_apple_charts","in_deezer_charts","bpm","danceability_%","valence_%","energy_%","acousticness_%","instrumentalness_%","liveness_%","speechiness_%","more_two_artists"],"y":["artist_count","released_year","released_month","released_day","in_spotify_playlists","in_spotify_charts","streams","in_apple_playlists","in_apple_charts","in_deezer_charts","bpm","danceability_%","valence_%","energy_%","acousticness_%","instrumentalness_%","liveness_%","speechiness_%","more_two_artists"],"z":[[1.0,0.0735643557900106,0.033856605368275776,-0.014761747140203497,-0.08522637531717166,-0.008570061483346643,-0.1097599524043898,-0.017024010627522523,-0.07527140676231472,0.020584939685693523,-0.058843659371359144,0.2140780153629738,0.12365013527243766,0.13752971396573355,-0.09470350886704695,-0.06126890027505064,0.03435375353058178,0.13148592291378983,0.8020761968064459],[0.0735643557900106,1.0,0.07643869857239981,0.16637665154446765,-0.3907293115530166,0.06867872145994551,-0.24272579089008642,-0.20147449681379845,0.0034787869408798265,0.09574147745073561,-0.011569547380703062,0.21503163783892068,-0.047642798848288384,0.07888637478143104,-0.13322358852373312,-0.02395830692694295,0.008488833640366763,0.12988657481527743,0.10944385379390209],[0.033856605368275776,0.07643869857239981,1.0,0.0577841849237184,-0.12240731512240241,-0.05018640797434948,-0.04604125957096039,-0.03402850515527687,-0.017812891521966648,0.006942239331867263,-0.0493999786437421,-0.05480810569147382,-0.11035481332072888,-0.08689743360147519,0.05504626589857863,0.03548115743375766,0.0013290126741325953,0.042127027471914116,0.020382805246358108],[-0.014761747140203497,0.16637665154446765,0.0577841849237184,1.0,-0.10761588105011606,0.01606797898531504,-0.025116479922823516,-0.011915957650662837,0.007726559219350334,0.05542631800561091,-0.03339376399725477,0.08424386875772844,0.0627513964277264,0.047318310687688075,0.000785350093012633,0.023039799533547588,-0.011094475833796878,-0.014602271061557152,0.012941835668055],[-0.08522637531717166,-0.3907293115530166,-0.12240731512240241,-0.10761588105011606,1.0,0.14134295883900183,0.7804038503763728,0.6883161979283439,0.21567604568348178,0.10128346186874354,-0.03448250366594356,-0.09698077610744844,-0.029822793802813517,0.035874838704220646,-0.06463303527122205,-0.0245697139461465,-0.051972862448203296,-0.07761034200340308,-0.08397689791319135],[-0.008570061483346643,0.06867872145994551,-0.05018640797434948,0.01606797898531504,0.14134295883900183,1.0,0.21403395317007556,0.20820175691115383,0.5568043244366212,0.56616140561665,0.028830466136862198,0.05133788325737562,0.05003993254209327,0.10496336396034457,-0.0728525875661891,-0.005813736127305587,-0.026581690296990222,-0.09410226165435152,0.04369354857658013],[-0.1097599524043898,-0.24272579089008642,-0.04604125957096039,-0.025116479922823516,0.7804038503763728,0.21403395317007556,1.0,0.7353207638877904,0.2691374652573007,0.18432853415873934,-0.02569384650556196,-0.09326818058629731,-0.051013689528639834,-0.036499273297597605,-0.0057509692186726155,-0.03303871464204409,-0.05666398078034252,-0.09996806352926553,-0.08840020521027003],[-0.017024010627522523,-0.20147449681379845,-0.03402850515527687,-0.011915957650662837,0.6883161979283439,0.20820175691115383,0.7353 ...

# %% [markdown]
# f) ¿Cuáles son las variables que mejor predicen un hit? **(1 puntos)**

# %%
df['hit'] = df["streams"] > df["streams"].quantile(0.5)
print(df.hit.describe())


df['key'] = df['key'].astype('category')
df['mode'] = df['mode'].astype('category')

X = df[['bpm',
        'danceability_%','valence_%','energy_%',
        'acousticness_%','instrumentalness_%','liveness_%',
        'speechiness_%', 'more_two_artists', 'artist_count']]

y = df['hit']

print(X.head())

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 123)

clf_log = Pipeline(steps=[
    ('scaler', StandardScaler()),
    ("glm", LogisticRegression(max_iter=10000, tol=0.1)),
])


# clf_log = LogisticRegression(max_iter=10000, tol=0.1)
clf_log.fit(X_train, y_train)

predictions = clf_log.predict(X_test)

print("Classification report")
print(classification_report(y_test, predictions))

print("Confusion matrix")
print(confusion_matrix(y_test, predictions))

lmc = clf_log.named_steps['glm'].coef_

# Plot for LM
objects = X.columns
y_pos = np.arange(len(objects))
coefficients = lmc[0]


fig = go.Figure()

# Agrego las trazas necesarias
fig.add_trace(
    go.Bar(
        x = coefficients,
        y = objects,
        name = "Coeficientes",
        orientation='h'
    )
)

# Actualizo el diseño
fig.update_layout(title = "GLM coefficients importance", xaxis_title = "Coeficientes normalizados", yaxis_title = "Variables")

# Muestro la figura
fig.show()

plt.show()
# Out:
# count       817
# unique        2
# top       False
# freq        409
# Name: hit, dtype: object
#    bpm  danceability_%  valence_%  energy_%  acousticness_%  \
# 0  125              80         89        83              31
# 1   92              71         61        74               7
# 2  138              51         32        53              17
# 3  170              55         58        72              11
# 4  144              65         23        80              14
#
#    instrumentalness_%  liveness_%  speechiness_%  more_two_artists  \
# 0                   0           8              4              True
# 1                   0          10              4             False
# 2                   0          31              6             False
# 3                   0          11             15             False
# 4                  63          11              6             False
#
#    artist_count
# 0             2
# 1             1
# 2             1
# 3             1
# 4             1
# Classification report
#               precision    recall  f1-score   support
#
#        False       0.56      0.46      0.50        85
#         True       0.51      0.61      0.55        79
#
#     accuracy                           0.53       164
#    macro avg       0.53      0.53      0.53       164
# weighted avg       0.53      0.53      0.53       164
#
# Confusion matrix
# [[39 46]
#  [31 48]]
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="4e5527be-1f61-4479-a54e-c151c0337397" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4e5527be-1f61-4479-a54e-c151c0337397")) {                    Plotly.newPlot(                        "4e5527be-1f61-4479-a54e-c151c0337397",                        [{"name":"Coeficientes","orientation":"h","x":[0.013904148510895269,-0.18509228412689324,-0.040399893983116046,-0.09707081346156671,-0.10060661363510985,-0.0354966206131804,-0.1867299778749886,-0.20045966225636971,0.09809419182712095,-0.25040300829872997],"y":["bpm","danceability_%","valence_%","energy_%","acousticness_%","instrumentalness_%","liveness_%","speechiness_%","more_two_artists","artist_count"],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo" ...

# %% [markdown]
# g) Agrupa los 4 gráficos realizados en uno solo y haz una recomendación a un sello discográfico para producir un nuevo hit. **(1 puntos)**

# %%
from plotly.subplots import make_subplots

# Creo el objeto que me permite hacer 4 gráficas al mismo tiempo
fig = make_subplots(rows = 2,
                    cols = 2,
                    subplot_titles=("Distribución reproducciones", "Diferencia #artistas",
                                    "Correlaciones",
                                    "Coeficientes"))


# Primer gráfico
fig.add_trace(
    go.Histogram(
        x=df['streams'],
        histnorm='probability'
    ),
    row = 1,
    col = 1
)

# Segundo gráfico
fig.add_trace(
    go.Box(
        x = df[df['more_two_artists'] == True]["streams"],
        marker_color = "gold",
        name = "Más de dos",
        boxpoints='all',
        boxmean=True
    ),
    row = 1,
    col = 2
)

fig.add_trace(
    go.Box(
        x = df[df['more_two_artists'] == False]["streams"],
        marker_color = "mediumseagreen",
        name = "Un solo artista",
        boxpoints='all',
        boxmean=True
    ),
    row = 1,
    col = 2
)



# Tercer gráfico
fig.add_trace(
    go.Heatmap(
        z=df.corr().to_numpy(),
        x=df.corr().columns,
        y=df.corr().columns
    ),
    row = 2,
    col = 1
)

# Cuarto gráfico
fig.add_trace(
    go.Bar(
        x = coefficients,
        y = objects,
        orientation='h'
    ),
    row = 2,
    col = 2
)

# Modifico las dimensiones totales y el titulo global
fig.update_layout(width = 950, height = 950, title = "Top Streamed Spotify Songs", bargap = 0.1)

fig.update_xaxes(title_text = "Reproducciones", row = 1, col = 1)

fig.update_yaxes(title_text = "Frecuencia", row = 1, col = 1)
fig.update_xaxes(title_text = "Reproducciones", row = 1, col = 2)

fig.update_xaxes(title_text = "Coeficientes", row = 2, col = 2)

fig.show()
# Out:
# <ipython-input-54-b7fb8d52c1cd>:51: FutureWarning:
#
# The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#
# <ipython-input-54-b7fb8d52c1cd>:52: FutureWarning:
#
# The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#
# <ipython-input-54-b7fb8d52c1cd>:53: FutureWarning:
#
# The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="2c331d95-02d3-43df-af0e-c5f3d56f954e" class="plotly-graph-div" style="height:950px; width:950px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2c331d95-02d3-43df-af0e-c5f3d56f954e")) {                    Plotly.newPlot(                        "2c331d95-02d3-43df-af0e-c5f3d56f954e",                        [{"histnorm":"probability","x":[141381703.0,133716286.0,140003974.0,800840817.0,303236322.0,183706234.0,725980112.0,58149378.0,95217315.0,553634067.0,505671438.0,58255150.0,387570742.0,1163093654.0,496795686.0,335222234.0,363369738.0,86444842.0,52135248.0,200647221.0,115364561.0,78300654.0,899183384.0,61245289.0,429829812.0,127408954.0,22581161.0,52294266.0,843957510.0,999748277.0,618990393.0,188933502.0,1355959075.0,786181836.0,176553476.0,354495408.0,2808096550.0,1109433169.0,1047101291.0,570515054.0,1647990401.0,2565529693.0,518745108.0,107753850.0,177740666.0,153372011.0,57876440.0,256483385.0,1214083358.0,111947664.0,156338624.0,720434240.0,357925728.0,674072710.0,1755214421.0,404562836.0,373199958.0,14780425.0,39578178.0,54266102.0,751134527.0,1356565093.0,1592909789.0,635412045.0,1230675890.0,585695368.0,43857627.0,2009094673.0,600976848.0,39709092.0,39228929.0,2665343922.0,223633238.0,1440757818.0,165484133.0,58054811.0,157058870.0,95131998.0,250305248.0,685032533.0,38411956.0,144565150.0,127567540.0,399686758.0,983637508.0,118482347.0,882831184.0,286400165.0,172825906.0,1241559043.0,29562220.0,77309611.0,1605224506.0,1116995633.0,838079900.0,1163620694.0,1093605526.0,179659294.0,39058561.0,36912123.0,1205951614.0,1791000570.0,201660859.0,248088961.0,90839753.0,607123776.0,55842345.0,211050784.0,342897938.0,2762.0,601863821.0,1953533826.0,2355719893.0,66902503.0,96273746.0,430977451.0,284819874.0,721975598.0,276259178.0,54225632.0,2559529074.0,681583126.0,2594040133.0,81102253.0,11956641.0,1687664027.0,611700552.0,1133865788.0,1089402494.0,411747614.0,255932395.0,31873544.0,233801632.0,1481349984.0,142095275.0,2011464183.0,436027885.0,2713922350.0,621660989.0,950906471.0,1593270737.0,1410088830.0,1235005533.0,1374581173.0,94186466.0,1788326445.0,1840364617.0,143573775.0,684675814.0,1113838873.0,1267333350.0,3562543890.0,1271293243.0,265882712.0,841749534.0,47956378.0,806397070.0,1641426668.0,2135158446.0,367316268.0,350381515.0,1264310836.0,30343206.0,405136812.0,540654286.0,57312735.0,397582059.0,1479115056.0,86773632.0,133753727.0,123124076.0,463564958.0,64533040.0,65496046.0,68616963.0,161460990.0,70106975.0,113509496.0,89933133.0,71007139.0,43522589.0,232896922.0,37126685.0,195576623.0,532336353.0,538115192.0,46142772.0,401036314.0,127026613.0,345031710.0,288101651.0,60350538.0,335074782.0,76767396.0,46065667.0,459276435.0,39666245.0,138517666.0,822633917.0,595900742.0,51985779.0,57945987.0,115010040.0,175097833.0,57089066.0,488386797.0,32761689.0,1047480053.0,153454328.0,217672943.0,457184829.0,726434358.0,573633020.0,1406111294.0,71573339.0,24975653.0,145458418.0,1424589568.0,231332117.0,415932686.0,988515741.0,50847624.0,39893489.0,92035115.0,118810253.0,77233241.0,117747907.0,266624541.0,293186992.0,139681964.0,123132751.0,103762518.0,162887075.0,91221625.0,190490915.0,96180277.0,185240616.0,885093467.0,104992946.0,147290338.0,158950978.0,76910644.0,137123880.0,782369383.0,502574952.0,207033255.0,381161027.0,466231982.0,357580552.0,61105704.0,198275403.0,705469769.0,34502215.0,304118600.0,1449799467.0,173627354.0,90025258.0,652704649.0,1829992958.0,655466831.0,146409671.0,95816024.0,117206995.0,100409613.0,80758350.0,325592432.0,58473276.0,52722996.0,191945597.0,77377503.0,743693613.0,267789608.0,449701773.0,67070410.0,116334601.0,165584767.0,367814306.0,477033549.0,156214700.0,448843705.0,294352144.0,972164968.0,920045682.0,2420461338.0,244658767.0,68216992 ...
